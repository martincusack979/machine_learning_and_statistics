# %% [markdown]
# # Tasks
#
# ### Machine Learning and Statistics
#
# Martin Cusack
#
# Student I.D: G00239124
#
# ***

# %% [markdown]
# ## How to use this repository
#
# Run using Python version 3.9.18
#
# ***

# %% [markdown]
# ### Task 1
#
# > Square roots are difficult to calculate. In Python, you typically use the power operator (a double asterisk) or a package such
# as `math`.  In this task,1 you should write a function `sqrt(x)` to approximate the square root of a floating point number x without
# using the power operator or a package.
#
# > Rather, you should use the Newton’s method. Start with an initial guess for the square root called $z0$. You then repeatedly
# improve it using the following formula, until the difference between some previous guess $zi$ and the next $zi+1$
# is less than some threshold, say 0.01.
#
# $$ z_{1 +1} = z_1 - \frac{zi × zi − x}{2z_i} $$

# %%
def sqrt(x): 
    # Initial guess for the square root
    z = x / 4.0
    
    # Loop until we are accurate enough
    for i in range (100):
        # Newton's method for a better approximation
        z = z - ((z * z - x) /(2 * z))
    
    # z should now be a good approximation for the square root
        
    return z

# %%
# test the function on 3
sqrt(3)
# Out:
# 1.7320508075688774

# %%
# check python's value for square root of 3
3**0.5
# Out:
# 1.7320508075688772

# %%
# the number that we want to calculate the square root of

x = 16

# %%
# initial guess for square root

z = 3.0

# %%
# first approximation
z = z - ((z * z - x) /(2 * z))

print (z)
# Out:
# 4.166666666666667

# %% [markdown]
# ***
# ## End
# ***

# %% [markdown]
# ### Task 2
#
# Consider the below contingency table based on a survey asking respondents whether they prefer coffee or tea and whether they
# prefer plain or chocolate biscuits. Use scipy.stats to perform a chi-squared test to see whether there is any evidence of an
# association between drink preference and biscuit preference in this instance.

# %% [markdown]
# ![contingency.png](attachment:contingency.png)

# %%
# Import pandas, random and scipy.stats packages

import pandas as pd
import scipy

import random

# %%
import scipy.stats as ss
print(scipy.__version__)
# Out:
# 1.11.3

# %%
import scipy.stats as ss

# %%
# Forty-three coffee drinkers who preferred chocolate biscuits
coffee_choc = [['Coffee', 'Chocolate']] * 43

# Show
coffee_choc
# Out:
# [['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
# ...

# %%
# Fifty-seven coffee drinkers who preferred plain biscuits
coffee_plain = [['Coffee', 'Plain']] * 57

# Show
coffee_plain
# Out:
# [['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
# ...

# %%
# Fifty-six tea drinkers who preferred chocolate biscuits
tea_choc = [['Tea', 'Chocolate']] * 56

# Show
tea_choc
# Out:
# [['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
# ...

# %%
# Forty-five tea drinkers who preferred plain biscuits
tea_plain = [['Tea', 'Plain']] * 45

# Show
tea_plain
# Out:
# [['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain']]

# %%
# Raw data, merge the four lists.
raw_data = coffee_choc + coffee_plain + tea_choc + tea_plain

# Show.
raw_data
# Out:
# [['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
# ...

# %%
# Shuffle the data.
random.shuffle(raw_data)

# Show.
raw_data
# Out:
# [['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
# ...

# %%
# Zip the list - make the rows columns and the columns rows.
# Interchanges the outer and inner lists.
drink, biscuit = list(zip(*raw_data))

# Show.
drink, biscuit
# Out:
# (('Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
# ...

# %%
# Create data frame
df = pd.DataFrame({'drink': drink, 'biscuit': biscuit})

# Show
df
# Out:
#       drink    biscuit
# 0       Tea  Chocolate
# 1       Tea      Plain
# 2    Coffee      Plain
# 3    Coffee      Plain
# 4       Tea  Chocolate
# ..      ...        ...
# 196     Tea  Chocolate
# 197  Coffee  Chocolate
# 198     Tea      Plain
# 199     Tea  Chocolate
# 200  Coffee      Plain
#
# [201 rows x 2 columns]

# %% [markdown]
# ## Contingency Table
#
# ***

# %%
# Crosstabs Contingency
cross = ss.contingency.crosstab(df['drink'], df['biscuit'])

#Show
cross
# Out:
# CrosstabResult(elements=(array(['Coffee', 'Tea'], dtype=object), array(['Chocolate', 'Plain'], dtype=object)), count=array([[43, 57],
#        [56, 45]]))

# %%
# The first variable values, and the second.
first, second = cross.elements

# Show.
first, second
# Out:
# (array(['Coffee', 'Tea'], dtype=object),
#  array(['Chocolate', 'Plain'], dtype=object))

# %%
# The counts.
cross.count
# Out:
# array([[43, 57],
#        [56, 45]])

# %% [markdown]
# ## Statistical Test

# %%
# the counts
cross.count
# Out:
# array([[43, 57],
#        [56, 45]])

# %%
# Run statistics
result = ss.chi2_contingency(cross.count, correction=False)

# Show
result
# Out:
# Chi2ContingencyResult(statistic=3.113937364324669, pvalue=0.07762509678333357, dof=1, expected_freq=array([[49.25373134, 50.74626866],
#        [49.74626866, 51.25373134]]))

# %% [markdown]
# ***
# ## End
# ***

# %% [markdown]
# ### Task 3
#
# Perform a t-test on the famous penguins data set to investigate whether there is evidence of a significant difference in the body
# mass of male and female gentoo penguins

# %%
# plots
import matplotlib.pyplot as plt

# data frames
import pandas

# numerical arrays
import numpy as np

# statistics
import scipy.stats as ss

# %% [markdown]
# ## Independent Samples t-test
#
# ***

# %%
# Load Penguins.
df = pandas.read_csv("Data\penguins.csv")

# Show.
df.head(12)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
#
#     body_mass_g     sex
# ...

# %%
# Body mass of Male penguins
sample_a = df[df['sex'] == 'MALE']['body_mass_g']

sample_a
# Out:
# 0      3750.0
# 5      3650.0
# 7      4675.0
# 13     3800.0
# 14     4400.0
#         ...
# 333    5500.0
# 335    5850.0
# 337    6000.0
# 341    5750.0
# 343    5400.0
# Name: body_mass_g, Length: 168, dtype: float64

# %%
# Body mass of Female penguins
sample_b = df[df['sex'] == 'FEMALE']['body_mass_g']

sample_b
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 332    4650.0
# 334    4375.0
# 338    4925.0
# 340    4850.0
# 342    5200.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
# independent t-test
ss.ttest_ind(sample_a, sample_b)
# Out:
# TtestResult(statistic=8.541720337994516, pvalue=4.897246751596224e-16, df=331.0)

# %% [markdown]
# ***
# ## End
# ***

# %% [markdown]
# ### Task 4
#
# Using the famous iris data set, suggest whether the setosa class is easily separable from the other two classes. Provide evidence
# for your answer.

# %%
# import scikit learn, pandas and numpy
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier  
import pandas as pd
import numpy as np

# %% [markdown]
# The Iris data set is based on measurements taken from three different species of Iris flower: Setosa, Versicolor and Virginica.  There are four measurements provided for each sample of these species:  sepal length, sepal width, petal length and petal width.  One way of establishing whether the setosa class of Iris flower is easily separable from the other two classes is to train a machine learning algorithm (such as K Nearest Neighbours) so that it can make predictions on which class a data point could belong to based on the available information. We can then produce a visualisation to further illustrate whether the setosa class is in fact easily separable from the other two classes.

# %%
# import Iris data set CSV file and convert to pandas data frame
df = pd.read_csv('Data\iris.csv')
# show
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Drop all rows with null values from data set
df_nona = df.dropna()

# show
df_nona
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# store X values.
X = df_nona[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# Show.
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# store y values.
y = df_nona['class']

# Show.
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: class, Length: 150, dtype: object

# %%
# Create a new instance of a classifier.
from sklearn.neighbors import KNeighborsClassifier
clf = sk.neighbors.KNeighborsClassifier()


# Fit the data.
clf.fit(X, y)
# Out:
# KNeighborsClassifier()

# %%
# Check that the classifier correctly predicts first X sample.
clf.predict(X.iloc[:1])
# Out:
# array(['setosa'], dtype=object)

# %%
# Keep 70% for testing, train on remaining 30%
X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(X, y, test_size = 0.3)

# %%
# Training inputs
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 90            5.5          2.6           4.4          1.2
# 44            5.1          3.8           1.9          0.4
# 70            5.9          3.2           4.8          1.8
# 84            5.4          3.0           4.5          1.5
# 126           6.2          2.8           4.8          1.8
# ..            ...          ...           ...          ...
# 3             4.6          3.1           1.5          0.2
# 31            5.4          3.4           1.5          0.4
# 131           7.9          3.8           6.4          2.0
# 143           6.8          3.2           5.9          2.3
# 49            5.0          3.3           1.4          0.2
#
# [105 rows x 4 columns]

# %%
# Training outputs
y_train
# Out:
# 90     versicolor
# 44         setosa
# 70     versicolor
# 84     versicolor
# 126     virginica
#           ...
# 3          setosa
# 31         setosa
# 131     virginica
# 143     virginica
# 49         setosa
# Name: class, Length: 105, dtype: object

# %%
# Create new instance of a classifier and fit the data
clf = sk.neighbors.KNeighborsClassifier()

clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predict based on test set
clf.predict(X_test)
# Out:
# array(['versicolor', 'virginica', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'virginica',
#        'setosa', 'virginica', 'versicolor', 'virginica', 'versicolor',
#        'virginica', 'versicolor', 'virginica', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'setosa', 'setosa', 'setosa', 'virginica', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'virginica', 'virginica',
#        'versicolor', 'virginica', 'virginica', 'setosa', 'versicolor',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa'], dtype=object)

# %%
# Proportion of correct classifications
(clf.predict(X_test) == y_test).sum() / X_test.shape[0]
# Out:
# 0.9555555555555556

# %% [markdown]
# ## Cross Validation

# %%
# Create a new instance of a classifier.
clf = sk.neighbors.KNeighborsClassifier()

# Run cross-validation with five folds.
sk.model_selection.cross_val_score(clf, X, y)
# Out:
# array([0.96666667, 1.        , 0.93333333, 0.96666667, 1.        ])

# %% [markdown]
# As seen above, when we used the K nearest neighbors classifier to run predictions on the test set it correctly predicted 96% of the samples.  This indicates that the classes are generally separable, but have a limited degree of overlap between data points. To check whether the Setosa class is easily separable from the other classes, we can create two-dimensional plots using Seaborn to illustrate this.

# %%
# create two-dimensional visualisations using Seaborn

import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('Data\iris.csv')
sns.FacetGrid(df, hue="class", height = 5).map(plt.scatter,"sepal_length","sepal_width").add_legend()
sns.FacetGrid(df, hue="class", height = 5).map(plt.scatter,"petal_length","petal_width").add_legend()
# Out:
# c:\Users\cusac\anaconda33\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\cusac\anaconda33\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# As we can see from the above 2-dimensional visualisations, the Setosa class is clearly separable from the other classes, while there is a degree of overlap between the Virginica and Versicolor classes.

# %% [markdown]
# ***
# ## End
# ***

# %% [markdown]
# ### Task 5
#
# Perform Principal Component Analysis on the iris data set, reducing the number of dimensions to two. Explain the purpose
# of the analysis and your results.

# %%
# Import pandas, scikit learn, scipy, matplotlib and seaborn

import pandas as pd

import sklearn as sk

import sklearn.neighbors as ne

import sklearn.preprocessing as pre

import sklearn.decomposition as dec

import scipy.stats as ss

import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# Principal component analysis (PCA) is a useful tool for interpreting and analysing multi-dimensional data, such as the Iris data set.  It can be used in conjunction with Seaborn to create 2-dimensional visualisations which allow us to gain valuable insights and to determine the separability of the data. In this task we will take the four variables in the Iris data set (sepal length, sepal width, petal length and petal width) and using PCA we will reduce the dimensionality of the data to gain a better understanding of the variables in the Iris data set.

# %%
# Load Iris data set.
df = pd.read_csv('data/iris.csv')

# Show.
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Drop rows with null values
df = df.dropna()

# Show.
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# display data frame of independent variables in the Iris data set

# Independent variables.
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# Show X
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# We can now create a new instance of PCA, specifying the number of variables required as 2 by using the "n_components" parameter.  We then fit the data to PCA

# %%
# Create new PCA instance.
pca = dec.PCA(n_components=2)

# %%
# Fit data to PCA
pca.fit(X)
# Out:
# PCA(n_components=2)

# %% [markdown]
# We can apply dimensionality reduction to the data using the "transform" method

# %%
# Apply dimensionality reduction with transform method and show
X_pca = pca.transform(X)


X_pca
# Out:
# array([[-2.68420713,  0.32660731],
#        [-2.71539062, -0.16955685],
#        [-2.88981954, -0.13734561],
#        [-2.7464372 , -0.31112432],
#        [-2.72859298,  0.33392456],
#        [-2.27989736,  0.74778271],
#        [-2.82089068, -0.08210451],
#        [-2.62648199,  0.17040535],
#        [-2.88795857, -0.57079803],
#        [-2.67384469, -0.1066917 ],
#        [-2.50652679,  0.65193501],
#        [-2.61314272,  0.02152063],
#        [-2.78743398, -0.22774019],
#        [-3.22520045, -0.50327991],
#        [-2.64354322,  1.1861949 ],
#        [-2.38386932,  1.34475434],
#        [-2.6225262 ,  0.81808967],
#        [-2.64832273,  0.31913667],
#        [-2.19907796,  0.87924409],
#        [-2.58734619,  0.52047364],
#        [-2.3105317 ,  0.39786782],
#        [-2.54323491,  0.44003175],
#        [-3.21585769,  0.14161557],
#        [-2.30312854,  0.10552268],
#        [-2.35617109, -0.03120959],
#        [-2.50791723, -0.13905634],
#        [-2.469056  ,  0.13788731],
# ...

# %%
# Original classification
df_pca = pd.DataFrame(df[['class']])

# Show.
df_pca
# Out:
#          class
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
# Incorporate the PCA variables
df_pca['pca0'] = X_pca[:, 0]
df_pca['pca1'] = X_pca[:, 1]

# Show.
df_pca
# Out:
#          class      pca0      pca1
# 0       setosa -2.684207  0.326607
# 1       setosa -2.715391 -0.169557
# 2       setosa -2.889820 -0.137346
# 3       setosa -2.746437 -0.311124
# 4       setosa -2.728593  0.333925
# ..         ...       ...       ...
# 145  virginica  1.944017  0.187415
# 146  virginica  1.525664 -0.375021
# 147  virginica  1.764046  0.078519
# 148  virginica  1.901629  0.115877
# 149  virginica  1.389666 -0.282887
#
# [150 rows x 3 columns]

# %%
# Pair plot.
sns.pairplot(df_pca, hue='class')
# Out:
# c:\Users\cusac\anaconda33\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# From the above visualisation, carried out after using PCA to reduce the dimensions of the data set, we can see that the Setosa class is clearly separable from the other classes. However, the Versicolor and Virginica classes are much closer together in proximity and share a degree of overlap. This would mean that a basic machine learning classifier, such as K Nearest Neighbours, may have some difficulty separating the classes.  In the following cells we will run Principal Component Analysis again, only this time we will use a standard scaler to further transform the data set so that each of the numerical variables is centered on 0, with a variance of 1.  This ultimately should allow K Nearest Neighbours to make more effective predictions based on the available data.

# %%
# Create instance of a standard scaler and fit the data to the scaler
scaler = pre.StandardScaler()

scaler.fit(X)
# Out:
# StandardScaler()

# %%
# Transformed X array.
X_transformed = scaler.transform(X)

# Show.
X_transformed
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
# Recreate data frame.
df_X_trans = pd.DataFrame(X_transformed, columns=X.columns)

# Show the scaled data
df_X_trans
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0       -0.900681     1.032057     -1.341272    -1.312977
# 1       -1.143017    -0.124958     -1.341272    -1.312977
# 2       -1.385353     0.337848     -1.398138    -1.312977
# 3       -1.506521     0.106445     -1.284407    -1.312977
# 4       -1.021849     1.263460     -1.341272    -1.312977
# ..            ...          ...           ...          ...
# 145      1.038005    -0.124958      0.819624     1.447956
# 146      0.553333    -1.281972      0.705893     0.922064
# 147      0.795669    -0.124958      0.819624     1.053537
# 148      0.432165     0.800654      0.933356     1.447956
# 149      0.068662    -0.124958      0.762759     0.790591
#
# [150 rows x 4 columns]

# %%
# Create a new instance of PCA 
pca = dec.PCA(n_components=2)

# Fit the scaled data to PCA
pca.fit(df_X_trans)

# Transform X_trans data frame
X_trans_pca = pca.transform(df_X_trans)

# Original classifications
df_trans_pca = pd.DataFrame(df[['class']])

# Incorporate our PCA variables.
df_trans_pca['pca0'] = X_trans_pca[:, 0]
df_trans_pca['pca1'] = X_trans_pca[:, 1]

# Show.
df_trans_pca
# Out:
#          class      pca0      pca1
# 0       setosa -2.264542  0.505704
# 1       setosa -2.086426 -0.655405
# 2       setosa -2.367950 -0.318477
# 3       setosa -2.304197 -0.575368
# 4       setosa -2.388777  0.674767
# ..         ...       ...       ...
# 145  virginica  1.870522  0.382822
# 146  virginica  1.558492 -0.905314
# 147  virginica  1.520845  0.266795
# 148  virginica  1.376391  1.016362
# 149  virginica  0.959299 -0.022284
#
# [150 rows x 3 columns]

# %%
# check the variance
pca.explained_variance_ratio_
# Out:
# array([0.72770452, 0.23030523])

# %%
# use Seaborn to create pairplot visualisation

sns.pairplot(df_trans_pca, hue='class')
# Out:
# c:\Users\cusac\anaconda33\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# As we can see from the above plot, it remains difficult to separate the Versicolor and Virginica classes, even after running PCA again with the scaled data.

# %% [markdown]
# ## Running K Nearest Neighbours on the scaled data
# ***

# %%
# Load the data.
df = pd.read_csv('data/iris.csv').dropna()

# Create new instance of Nearest Neighbours classifier
clf = sk.neighbors.KNeighborsClassifier()

# X data

X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
  
# Create instance of a standard scaler and fit the data to the scaler
  
scaler = pre.StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# y data.
y = df['class']

# Run cross-validation with five folds
sk.model_selection.cross_val_score(clf, X, y)
# Out:
# array([0.96666667, 0.96666667, 0.93333333, 0.93333333, 1.        ])

# %% [markdown]
# As we can see from the above score, the K Nearest Neighbours classifier performs exceptionally well when it makes predictions on the scaled data.  This illustrates the importance of using a scaler before performing machine learning operations on a given set of data. While it might be a somewhat surprising result, considering the slight overlap between Versicolor and Virginia which was evident after performing Principal Component Analysis, the high score achieved by K Nearest Neighbours here suggests it would be highly effective at distinguishing between thee three different classes in the Iris data set.

# %% [markdown]
# ***
#
# ## End
#
# ***
