# %% [markdown]
# # Tasks
#
# ### Machine Learning and Statistics
#
# Martin Cusack
#
# Student I.D: G00239124
#
# ***

# %% [markdown]
# ### Task 1
#
# > Square roots are difficult to calculate. In Python, you typically use the power operator (a double asterisk) or a package such
# as `math`.  In this task,1 you should write a function `sqrt(x)` to approximate the square root of a floating point number x without
# using the power operator or a package.
#
# > Rather, you should use the Newton’s method. Start with an initial guess for the square root called $z0$. You then repeatedly
# improve it using the following formula, until the difference between some previous guess $zi$ and the next $zi+1$
# is less than some threshold, say 0.01.
#
# $$ z_{1 +1} = z_1 - \frac{zi × zi − x}{2z_i} $$

# %%
def sqrt(x): 
    # Initial guess for the square root
    z = x / 4.0
    
    # Loop until we are accurate enough
    for i in range (100):
        # Newton's method for a better approximation
        z = z - ((z * z - x) /(2 * z))
    
    # z should now be a good approximation for the square root
        
    return z

# %%
# test the function on 3
sqrt(3)
# Out:
# 1.7320508075688774

# %%
# check python's value for square root of 3
3**0.5
# Out:
# 1.7320508075688772

# %%
# the number that we want to calculate the square root of

x = 16

# %%
# initial guess for square root

z = 3.0

# %%
# first approximation
z = z - ((z * z - x) /(2 * z))

print (z)
# Out:
# 4.166666666666667

# %% [markdown]
# ***
# ## End
# ***

# %% [markdown]
# ### Task 2
#
# Consider the below contingency table based on a survey asking respondents whether they prefer coffee or tea and whether they
# prefer plain or chocolate biscuits. Use scipy.stats to perform a chi-squared test to see whether there is any evidence of an
# association between drink preference and biscuit preference in this instance.

# %% [markdown]
# ![contingency.png](attachment:contingency.png)

# %%
# Import pandas, random and scipy.stats packages

import pandas as pd
import scipy

import random

# %%
import scipy.stats as ss
print(scipy.__version__)
# Out:
# 1.11.3

# %%
import scipy.stats as ss

# %%
# Forty-three coffee drinkers who preferred chocolate biscuits
coffee_choc = [['Coffee', 'Chocolate']] * 43

# Show
coffee_choc
# Out:
# [['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate']]

# %%
# Fifty-seven coffee drinkers who preferred plain biscuits
coffee_plain = [['Coffee', 'Plain']] * 57

# Show
coffee_plain
# Out:
# [['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain']]

# %%
# Fifty-six tea drinkers who preferred chocolate biscuits
tea_choc = [['Tea', 'Chocolate']] * 56

# Show
tea_choc
# Out:
# [['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate']]

# %%
# Forty-five tea drinkers who preferred plain biscuits
tea_plain = [['Tea', 'Plain']] * 45

# Show
tea_plain
# Out:
# [['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain']]

# %%
# Raw data, merge the four lists.
raw_data = coffee_choc + coffee_plain + tea_choc + tea_plain

# Show.
raw_data
# Out:
# [['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain']]

# %%
# Shuffle the data.
random.shuffle(raw_data)

# Show.
raw_data
# Out:
# [['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Plain'],
#  ['Tea', 'Chocolate'],
#  ['Tea', 'Chocolate'],
#  ['Coffee', 'Plain']]

# %%
# Zip the list - make the rows columns and the columns rows.
# Interchanges the outer and inner lists.
drink, biscuit = list(zip(*raw_data))

# Show.
drink, biscuit
# Out:
# (('Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Tea',
#   'Coffee'),
#  ('Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Plain',
#   'Chocolate',
#   'Chocolate',
#   'Plain'))

# %%
# Create data frame
df = pd.DataFrame({'drink': drink, 'biscuit': biscuit})

# Show
df
# Out:
#       drink    biscuit
# 0    Coffee  Chocolate
# 1       Tea      Plain
# 2       Tea  Chocolate
# 3    Coffee      Plain
# 4    Coffee      Plain
# ..      ...        ...
# 196     Tea  Chocolate
# 197     Tea      Plain
# 198     Tea  Chocolate
# 199     Tea  Chocolate
# 200  Coffee      Plain
#
# [201 rows x 2 columns]

# %% [markdown]
# ## Contingency Table
#
# ***

# %%
# Crosstabs Contingency
cross = ss.contingency.crosstab(df['drink'], df['biscuit'])

#Show
cross
# Out:
# CrosstabResult(elements=(array(['Coffee', 'Tea'], dtype=object), array(['Chocolate', 'Plain'], dtype=object)), count=array([[43, 57],
#        [56, 45]]))

# %%
# The first variable values, and the second.
first, second = cross.elements

# Show.
first, second
# Out:
# (array(['Coffee', 'Tea'], dtype=object),
#  array(['Chocolate', 'Plain'], dtype=object))

# %%
# The counts.
cross.count
# Out:
# array([[43, 57],
#        [56, 45]])

# %% [markdown]
# ## Statistical Test

# %%
# the counts
cross.count
# Out:
# array([[43, 57],
#        [56, 45]])

# %%
# Run statistics
result = ss.chi2_contingency(cross.count, correction=False)

# Show
result
# Out:
# Chi2ContingencyResult(statistic=3.113937364324669, pvalue=0.07762509678333357, dof=1, expected_freq=array([[49.25373134, 50.74626866],
#        [49.74626866, 51.25373134]]))

# %% [markdown]
# ***
# ## End
# ***

# %% [markdown]
# ### Task 3
#
# Perform a t-test on the famous penguins data set3 to investigate whether there is evidence of a significant difference in the body
# mass of male and female gentoo penguins

# %%
# plots
import matplotlib.pyplot as plt

# data frames
import pandas

# numerical arrays
import numpy as np

# statistics
import scipy.stats as ss

# %% [markdown]
# ## Independent Samples t-test
#
# ***

# %%
# Load Penguins.
df = pandas.read_csv(r"C:\Users\cusac\penguins.csv")

# Show.
df.head(12)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\cusac\OneDrive\Desktop\GMIT\SEMESTER 4 - Machine Learning\MACHINE LEARNING AND STATISTICS\machine_learning_and_statistics\tasks.ipynb Cell 34 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/cusac/OneDrive/Desktop/GMIT/SEMESTER%204%20-%20Machine%20Learning/MACHINE%20LEARNING%20AND%20STATISTICS/machine_learning_and_statistics/tasks.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> # Load Penguins.
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cusac/OneDrive/Desktop/GMIT/SEMESTER%204%20-%20Machine%20Learning/MACHINE%20LEARNING%20AND%20STATISTICS/machine_learning_and_statistics/tasks.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> df = pandas.read_csv(r"C:\Users\cusac\penguins.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/cusac/OneDrive/Desktop/GMIT/SEMESTER%204%20-%20Machine%20Learning/MACHINE%20LEARNING%20AND%20STATISTICS/machine_learning_and_statistics/tasks.ipynb#X45sZmlsZQ%3D%3D?line=3'>4</a> # Show.
#       <a href='vscode-notebook-cell:/c%3A/Users/cusac/OneDrive/Desktop/GMIT/SEMESTER%204%20-%20Machine%20Learning/MACHINE%20LEARNING%20AND%20STATISTICS/machine_learning_and_statistics/tasks.ipynb#X45sZmlsZQ%3D%3D?line=4'>5</a> df.head(12)
#
# File c:\Users\cusac\anaconda33\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\cusac\anaconda33\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\cusac\anaconda33\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\cusac\anaconda33\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\cusac\anaconda33\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Users\cusac\anaconda33\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\cusac\\penguins.csv'

# %%
# Body mass of Male penguins
sample_a = df[df['sex'] == 'MALE']['body_mass_g']

sample_a
# Out:
# 0      3750.0
# 5      3650.0
# 7      4675.0
# 13     3800.0
# 14     4400.0
#         ...
# 333    5500.0
# 335    5850.0
# 337    6000.0
# 341    5750.0
# 343    5400.0
# Name: body_mass_g, Length: 168, dtype: float64

# %%
# Body mass of Female penguins
sample_b = df[df['sex'] == 'FEMALE']['body_mass_g']

sample_b
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 332    4650.0
# 334    4375.0
# 338    4925.0
# 340    4850.0
# 342    5200.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
# independent t-test
ss.ttest_ind(sample_a, sample_b)
# Out:
# TtestResult(statistic=8.541720337994516, pvalue=4.897246751596224e-16, df=331.0)

# %% [markdown]
# ### Task 4
#
# Using the famous iris data set, suggest whether the setosa class is easily separable from the other two classes. Provide evidence
# for your answer.

# %%
# import scikit learn and pandas
import sklearn as sk
import pandas as pd

# %%
# import iris data set .csv file and store as a pandas data frame
df = pd.read_csv('Data\iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Drop all rows with null values and show
df_nona = df.dropna()


df_nona
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# store X values.
X = df_nona[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# Show.
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# store y values.
y = df_nona['class']

# Show.
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: class, Length: 150, dtype: object
